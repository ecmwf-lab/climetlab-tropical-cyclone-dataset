# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install pyyaml==5.1 pycocotools>=2.0.1
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# !gcc --version
# Out:
# 1.6.0+cu101 True
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
assert torch.__version__.startswith("1.6")
#!pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.6/index.html

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
# %cd drive/My Drive
# Out:
# /content/drive/My Drive

# %%
# %cd cyc1440/
# Out:
# /content/drive/My Drive/cyc1440

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances('cyclone_ds_train', {}, 'bb40train.json', 'train')

# %%
cyclone_metadata = MetadataCatalog.get('cyclone_ds_train')

# %%
dataset_dicts = DatasetCatalog.get('cyclone_ds_train')
# Out:
# [09/12 20:57:45 d2.data.datasets.coco]: Loaded 3977 images in COCO format from bb40train.json

# %%
import random
from detectron2.utils.visualizer import Visualizer

for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=cyclone_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=720x240 at 0x7F195C1387B8>
# <PIL.Image.Image image mode=RGB size=720x240 at 0x7F195BEDA1D0>
# <PIL.Image.Image image mode=RGB size=720x240 at 0x7F195BF43A20>

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
import os

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_101_DC5_3x.yaml"))

# cfg.merge_from_file(
#     "./detectron2_repo/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
# )
cfg.DATASETS.TRAIN = ("cyclone_ds_train",)
cfg.DATASETS.TEST = ()  # no metrics implemented for this dataset
cfg.DATALOADER.NUM_WORKERS = 2
#cfg.MODEL.WEIGHTS = "detectron2://COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl"  # initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.002
cfg.SOLVER.MAX_ITER = (
    2000
)  # 300 iterations seems good enough, but you can certainly train longer
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = (
    1024
)  # faster, and good enough for this toy dataset
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 4  # 3 classes (data, fig, hazelnut)
cfg.INPUT.MAX_SIZE_TEST = 1440
cfg.INPUT.MAX_SIZE_TRAIN = 1440
cfg.INPUT.MIN_SIZE_TEST = 481
cfg.INPUT.MIN_SIZE_TRAIN = 481
cfg.MODEL.ANCHOR_GENERATOR.SIZES = [[30,40,50,60]]


os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [09/12 20:58:38 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): ResNet(
#     (stem): BasicStem(
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#     )
#     (res3): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#     )
#     (res4): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (4): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (5): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (6): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (7): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (8): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (9): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (10): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (11): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (12): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (13): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (14): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (15): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (16): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (17): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (18): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (19): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (20): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (21): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (22): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#     )
#     (res5): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(2048, 12, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(2048, 48, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=100352, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=16, bias=True)
#     )
#   )
# )
# [09/12 20:58:38 d2.data.datasets.coco]: Loaded 3977 images in COCO format from bb40train.json
# [09/12 20:58:38 d2.data.build]: Removed 0 images with no usable annotations. 3977 images left.
# [09/12 20:58:38 d2.data.build]: Distribution of instances among all 4 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   class0   | 7455         |   class1   | 7588         |   class2   | 4148         |
# |   class3   | 1116         |            |              |            |              |
# |   total    | 20307        |            |              |            |              |
# [09/12 20:58:38 d2.data.common]: Serializing 3977 elements to byte tensors and concatenating them all ...
# [09/12 20:58:38 d2.data.common]: Serialized dataset takes 1.33 MiB
# [09/12 20:58:38 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(481, 481), max_size=1440, sample_style='choice'), RandomFlip()]
# [09/12 20:58:38 d2.data.build]: Using training sampler TrainingSampler
# R-101.pkl: 179MB [00:02, 66.0MB/s]
# [09/12 20:58:42 d2.checkpoint.c2_model_loading]: Remapping C2 weights ......
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.bias                      loaded from res2_0_branch2a_bn_beta           of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.running_mean              loaded from res2_0_branch2a_bn_running_mean   of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.running_var               loaded from res2_0_branch2a_bn_running_var    of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.weight                    loaded from res2_0_branch2a_bn_gamma          of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.weight                         loaded from res2_0_branch2a_w                 of shape (64, 64, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.bias                      loaded from res2_0_branch2b_bn_beta           of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.running_mean              loaded from res2_0_branch2b_bn_running_mean   of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.running_var               loaded from res2_0_branch2b_bn_running_var    of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.weight                    loaded from res2_0_branch2b_bn_gamma          of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.weight                         loaded from res2_0_branch2b_w                 of shape (64, 64, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.bias                      loaded from res2_0_branch2c_bn_beta           of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.running_mean              loaded from res2_0_branch2c_bn_running_mean   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.running_var               loaded from res2_0_branch2c_bn_running_var    of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.weight                    loaded from res2_0_branch2c_bn_gamma          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.weight                         loaded from res2_0_branch2c_w                 of shape (256, 64, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.bias                   loaded from res2_0_branch1_bn_beta            of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.running_mean           loaded from res2_0_branch1_bn_running_mean    of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.running_var            loaded from res2_0_branch1_bn_running_var     of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.weight                 loaded from res2_0_branch1_bn_gamma           of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.weight                      loaded from res2_0_branch1_w                  of shape (256, 64, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.bias                      loaded from res2_1_branch2a_bn_beta           of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.running_mean              loaded from res2_1_branch2a_bn_running_mean   of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.running_var               loaded from res2_1_branch2a_bn_running_var    of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.weight                    loaded from res2_1_branch2a_bn_gamma          of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.weight                         loaded from res2_1_branch2a_w                 of shape (64, 256, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.bias                      loaded from res2_1_branch2b_bn_beta           of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.running_mean              loaded from res2_1_branch2b_bn_running_mean   of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.running_var               loaded from res2_1_branch2b_bn_running_var    of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.weight                    loaded from res2_1_branch2b_bn_gamma          of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.weight                         loaded from res2_1_branch2b_w                 of shape (64, 64, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.norm.bias                      loaded from res2_1_branch2c_bn_beta           of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.norm.running_mean              loaded from res2_1_branch2c_bn_running_mean   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.norm.running_var               loaded from res2_1_branch2c_bn_running_var    of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.norm.weight                    loaded from res2_1_branch2c_bn_gamma          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.weight                         loaded from res2_1_branch2c_w                 of shape (256, 64, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv1.norm.bias                      loaded from res2_2_branch2a_bn_beta           of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv1.norm.running_mean              loaded from res2_2_branch2a_bn_running_mean   of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv1.norm.running_var               loaded from res2_2_branch2a_bn_running_var    of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv1.norm.weight                    loaded from res2_2_branch2a_bn_gamma          of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv1.weight                         loaded from res2_2_branch2a_w                 of shape (64, 256, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv2.norm.bias                      loaded from res2_2_branch2b_bn_beta           of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv2.norm.running_mean              loaded from res2_2_branch2b_bn_running_mean   of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv2.norm.running_var               loaded from res2_2_branch2b_bn_running_var    of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv2.norm.weight                    loaded from res2_2_branch2b_bn_gamma          of shape (64,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv2.weight                         loaded from res2_2_branch2b_w                 of shape (64, 64, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv3.norm.bias                      loaded from res2_2_branch2c_bn_beta           of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv3.norm.running_mean              loaded from res2_2_branch2c_bn_running_mean   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv3.norm.running_var               loaded from res2_2_branch2c_bn_running_var    of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv3.norm.weight                    loaded from res2_2_branch2c_bn_gamma          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res2.2.conv3.weight                         loaded from res2_2_branch2c_w                 of shape (256, 64, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv1.norm.bias                      loaded from res3_0_branch2a_bn_beta           of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv1.norm.running_mean              loaded from res3_0_branch2a_bn_running_mean   of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv1.norm.running_var               loaded from res3_0_branch2a_bn_running_var    of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv1.norm.weight                    loaded from res3_0_branch2a_bn_gamma          of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv1.weight                         loaded from res3_0_branch2a_w                 of shape (128, 256, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv2.norm.bias                      loaded from res3_0_branch2b_bn_beta           of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv2.norm.running_mean              loaded from res3_0_branch2b_bn_running_mean   of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv2.norm.running_var               loaded from res3_0_branch2b_bn_running_var    of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv2.norm.weight                    loaded from res3_0_branch2b_bn_gamma          of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv2.weight                         loaded from res3_0_branch2b_w                 of shape (128, 128, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv3.norm.bias                      loaded from res3_0_branch2c_bn_beta           of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv3.norm.running_mean              loaded from res3_0_branch2c_bn_running_mean   of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv3.norm.running_var               loaded from res3_0_branch2c_bn_running_var    of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv3.norm.weight                    loaded from res3_0_branch2c_bn_gamma          of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.conv3.weight                         loaded from res3_0_branch2c_w                 of shape (512, 128, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.shortcut.norm.bias                   loaded from res3_0_branch1_bn_beta            of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.shortcut.norm.running_mean           loaded from res3_0_branch1_bn_running_mean    of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.shortcut.norm.running_var            loaded from res3_0_branch1_bn_running_var     of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.shortcut.norm.weight                 loaded from res3_0_branch1_bn_gamma           of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.0.shortcut.weight                      loaded from res3_0_branch1_w                  of shape (512, 256, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv1.norm.bias                      loaded from res3_1_branch2a_bn_beta           of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv1.norm.running_mean              loaded from res3_1_branch2a_bn_running_mean   of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv1.norm.running_var               loaded from res3_1_branch2a_bn_running_var    of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv1.norm.weight                    loaded from res3_1_branch2a_bn_gamma          of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv1.weight                         loaded from res3_1_branch2a_w                 of shape (128, 512, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv2.norm.bias                      loaded from res3_1_branch2b_bn_beta           of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv2.norm.running_mean              loaded from res3_1_branch2b_bn_running_mean   of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv2.norm.running_var               loaded from res3_1_branch2b_bn_running_var    of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv2.norm.weight                    loaded from res3_1_branch2b_bn_gamma          of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv2.weight                         loaded from res3_1_branch2b_w                 of shape (128, 128, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv3.norm.bias                      loaded from res3_1_branch2c_bn_beta           of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv3.norm.running_mean              loaded from res3_1_branch2c_bn_running_mean   of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv3.norm.running_var               loaded from res3_1_branch2c_bn_running_var    of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv3.norm.weight                    loaded from res3_1_branch2c_bn_gamma          of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.1.conv3.weight                         loaded from res3_1_branch2c_w                 of shape (512, 128, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv1.norm.bias                      loaded from res3_2_branch2a_bn_beta           of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv1.norm.running_mean              loaded from res3_2_branch2a_bn_running_mean   of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv1.norm.running_var               loaded from res3_2_branch2a_bn_running_var    of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv1.norm.weight                    loaded from res3_2_branch2a_bn_gamma          of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv1.weight                         loaded from res3_2_branch2a_w                 of shape (128, 512, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv2.norm.bias                      loaded from res3_2_branch2b_bn_beta           of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv2.norm.running_mean              loaded from res3_2_branch2b_bn_running_mean   of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv2.norm.running_var               loaded from res3_2_branch2b_bn_running_var    of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv2.norm.weight                    loaded from res3_2_branch2b_bn_gamma          of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv2.weight                         loaded from res3_2_branch2b_w                 of shape (128, 128, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv3.norm.bias                      loaded from res3_2_branch2c_bn_beta           of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv3.norm.running_mean              loaded from res3_2_branch2c_bn_running_mean   of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv3.norm.running_var               loaded from res3_2_branch2c_bn_running_var    of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv3.norm.weight                    loaded from res3_2_branch2c_bn_gamma          of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.2.conv3.weight                         loaded from res3_2_branch2c_w                 of shape (512, 128, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv1.norm.bias                      loaded from res3_3_branch2a_bn_beta           of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv1.norm.running_mean              loaded from res3_3_branch2a_bn_running_mean   of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv1.norm.running_var               loaded from res3_3_branch2a_bn_running_var    of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv1.norm.weight                    loaded from res3_3_branch2a_bn_gamma          of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv1.weight                         loaded from res3_3_branch2a_w                 of shape (128, 512, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv2.norm.bias                      loaded from res3_3_branch2b_bn_beta           of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv2.norm.running_mean              loaded from res3_3_branch2b_bn_running_mean   of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv2.norm.running_var               loaded from res3_3_branch2b_bn_running_var    of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv2.norm.weight                    loaded from res3_3_branch2b_bn_gamma          of shape (128,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv2.weight                         loaded from res3_3_branch2b_w                 of shape (128, 128, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv3.norm.bias                      loaded from res3_3_branch2c_bn_beta           of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv3.norm.running_mean              loaded from res3_3_branch2c_bn_running_mean   of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv3.norm.running_var               loaded from res3_3_branch2c_bn_running_var    of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv3.norm.weight                    loaded from res3_3_branch2c_bn_gamma          of shape (512,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res3.3.conv3.weight                         loaded from res3_3_branch2c_w                 of shape (512, 128, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv1.norm.bias                      loaded from res4_0_branch2a_bn_beta           of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv1.norm.running_mean              loaded from res4_0_branch2a_bn_running_mean   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv1.norm.running_var               loaded from res4_0_branch2a_bn_running_var    of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv1.norm.weight                    loaded from res4_0_branch2a_bn_gamma          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv1.weight                         loaded from res4_0_branch2a_w                 of shape (256, 512, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv2.norm.bias                      loaded from res4_0_branch2b_bn_beta           of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv2.norm.running_mean              loaded from res4_0_branch2b_bn_running_mean   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv2.norm.running_var               loaded from res4_0_branch2b_bn_running_var    of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv2.norm.weight                    loaded from res4_0_branch2b_bn_gamma          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv2.weight                         loaded from res4_0_branch2b_w                 of shape (256, 256, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv3.norm.bias                      loaded from res4_0_branch2c_bn_beta           of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv3.norm.running_mean              loaded from res4_0_branch2c_bn_running_mean   of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv3.norm.running_var               loaded from res4_0_branch2c_bn_running_var    of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv3.norm.weight                    loaded from res4_0_branch2c_bn_gamma          of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.conv3.weight                         loaded from res4_0_branch2c_w                 of shape (1024, 256, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.shortcut.norm.bias                   loaded from res4_0_branch1_bn_beta            of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.shortcut.norm.running_mean           loaded from res4_0_branch1_bn_running_mean    of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.shortcut.norm.running_var            loaded from res4_0_branch1_bn_running_var     of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.shortcut.norm.weight                 loaded from res4_0_branch1_bn_gamma           of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.0.shortcut.weight                      loaded from res4_0_branch1_w                  of shape (1024, 512, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv1.norm.bias                      loaded from res4_1_branch2a_bn_beta           of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv1.norm.running_mean              loaded from res4_1_branch2a_bn_running_mean   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv1.norm.running_var               loaded from res4_1_branch2a_bn_running_var    of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv1.norm.weight                    loaded from res4_1_branch2a_bn_gamma          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv1.weight                         loaded from res4_1_branch2a_w                 of shape (256, 1024, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv2.norm.bias                      loaded from res4_1_branch2b_bn_beta           of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv2.norm.running_mean              loaded from res4_1_branch2b_bn_running_mean   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv2.norm.running_var               loaded from res4_1_branch2b_bn_running_var    of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv2.norm.weight                    loaded from res4_1_branch2b_bn_gamma          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv2.weight                         loaded from res4_1_branch2b_w                 of shape (256, 256, 3, 3)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv3.norm.bias                      loaded from res4_1_branch2c_bn_beta           of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv3.norm.running_mean              loaded from res4_1_branch2c_bn_running_mean   of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv3.norm.running_var               loaded from res4_1_branch2c_bn_running_var    of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv3.norm.weight                    loaded from res4_1_branch2c_bn_gamma          of shape (1024,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.1.conv3.weight                         loaded from res4_1_branch2c_w                 of shape (1024, 256, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv1.norm.bias                     loaded from res4_10_branch2a_bn_beta          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv1.norm.running_mean             loaded from res4_10_branch2a_bn_running_mean  of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv1.norm.running_var              loaded from res4_10_branch2a_bn_running_var   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv1.norm.weight                   loaded from res4_10_branch2a_bn_gamma         of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv1.weight                        loaded from res4_10_branch2a_w                of shape (256, 1024, 1, 1)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv2.norm.bias                     loaded from res4_10_branch2b_bn_beta          of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv2.norm.running_mean             loaded from res4_10_branch2b_bn_running_mean  of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv2.norm.running_var              loaded from res4_10_branch2b_bn_running_var   of shape (256,)
# [09/12 20:58:43 d2.checkpoint.c2_model_loading]: backbone.res4.10.conv2.norm.weight                   loaded from res4_10_branch2b_bn_gamma         of shape (256,)
# ...
# [09/12 21:11:06 d2.utils.events]:  eta: 0:27:59  iter: 599  total_loss: 0.201  loss_cls: 0.094  loss_box_reg: 0.031  loss_rpn_cls: 0.064  loss_rpn_loc: 0.013  time: 1.1961  data_time: 0.0045  lr: 0.001199  max_mem: 5484M
# [09/12 21:11:30 d2.utils.events]:  eta: 0:27:35  iter: 619  total_loss: 0.200  loss_cls: 0.087  loss_box_reg: 0.036  loss_rpn_cls: 0.062  loss_rpn_loc: 0.014  time: 1.1960  data_time: 0.0044  lr: 0.001239  max_mem: 5484M
# [09/12 21:11:54 d2.utils.events]:  eta: 0:27:10  iter: 639  total_loss: 0.175  loss_cls: 0.075  loss_box_reg: 0.030  loss_rpn_cls: 0.058  loss_rpn_loc: 0.013  time: 1.1959  data_time: 0.0043  lr: 0.001279  max_mem: 5484M
# [09/12 21:12:18 d2.utils.events]:  eta: 0:26:46  iter: 659  total_loss: 0.218  loss_cls: 0.099  loss_box_reg: 0.037  loss_rpn_cls: 0.063  loss_rpn_loc: 0.013  time: 1.1958  data_time: 0.0044  lr: 0.001319  max_mem: 5484M
# [09/12 21:12:43 d2.utils.events]:  eta: 0:26:22  iter: 679  total_loss: 0.205  loss_cls: 0.090  loss_box_reg: 0.034  loss_rpn_cls: 0.063  loss_rpn_loc: 0.012  time: 1.1981  data_time: 0.0880  lr: 0.001359  max_mem: 5484M
# [09/12 21:13:07 d2.utils.events]:  eta: 0:25:58  iter: 699  total_loss: 0.171  loss_cls: 0.076  loss_box_reg: 0.025  loss_rpn_cls: 0.055  loss_rpn_loc: 0.013  time: 1.1979  data_time: 0.0042  lr: 0.001399  max_mem: 5484M
# [09/12 21:36:36 d2.utils.events]:  eta: 0:02:24  iter: 1879  total_loss: 0.188  loss_cls: 0.092  loss_box_reg: 0.029  loss_rpn_cls: 0.056  loss_rpn_loc: 0.009  time: 1.1951  data_time: 0.0042  lr: 0.002000  max_mem: 5484M
# [09/12 21:37:00 d2.utils.events]:  eta: 0:02:00  iter: 1899  total_loss: 0.175  loss_cls: 0.082  loss_box_reg: 0.027  loss_rpn_cls: 0.056  loss_rpn_loc: 0.008  time: 1.1952  data_time: 0.0045  lr: 0.002000  max_mem: 5484M
# [09/12 21:37:24 d2.utils.events]:  eta: 0:01:36  iter: 1919  total_loss: 0.205  loss_cls: 0.103  loss_box_reg: 0.035  loss_rpn_cls: 0.064  loss_rpn_loc: 0.009  time: 1.1951  data_time: 0.0043  lr: 0.002000  max_mem: 5484M
# [09/12 21:37:48 d2.utils.events]:  eta: 0:01:12  iter: 1939  total_loss: 0.185  loss_cls: 0.092  loss_box_reg: 0.033  loss_rpn_cls: 0.058  loss_rpn_loc: 0.009  time: 1.1950  data_time: 0.0046  lr: 0.002000  max_mem: 5484M
# [09/12 21:38:12 d2.utils.events]:  eta: 0:00:48  iter: 1959  total_loss: 0.201  loss_cls: 0.100  loss_box_reg: 0.037  loss_rpn_cls: 0.050  loss_rpn_loc: 0.008  time: 1.1950  data_time: 0.0042  lr: 0.002000  max_mem: 5484M
# [09/12 21:38:35 d2.utils.events]:  eta: 0:00:25  iter: 1979  total_loss: 0.171  loss_cls: 0.088  loss_box_reg: 0.030  loss_rpn_cls: 0.050  loss_rpn_loc: 0.007  time: 1.1949  data_time: 0.0048  lr: 0.002000  max_mem: 5484M
# [09/12 21:39:46 d2.utils.events]:  eta: 0:00:01  iter: 1999  total_loss: 0.159  loss_cls: 0.082  loss_box_reg: 0.025  loss_rpn_cls: 0.050  loss_rpn_loc: 0.006  time: 1.1949  data_time: 0.0043  lr: 0.002000  max_mem: 5484M
# [09/12 21:39:46 d2.engine.hooks]: Overall training speed: 1997 iterations in 0:39:47 (1.1955 s / it)
# [09/12 21:39:46 d2.engine.hooks]: Total training time: 0:40:35 (0:00:48 on hooks)

# %%
#register_coco_instances('cyclone_ds_val', {}, '/content/drive/My Drive/cyc1440/val1.json', '/content/drive/My Drive/local1440/val')
register_coco_instances('cyclone_ds_val', {}, 'bb40val.json', 'val')

# %%
val_metadata = MetadataCatalog.get('cyclone_ds_val')
val_dicts = DatasetCatalog.get('cyclone_ds_val')
# Out:
# [09/12 21:42:15 d2.data.datasets.coco]: Loaded 1439 images in COCO format from bb40val.json

# %%
#print(cfg.OUTPUT_DIR)
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
#cfg.MODEL.WEIGHTS = '/content/drive/My Drive/cyc1440/output/model_final.pth'
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2 # set the testing threshold for this model
cfg.DATASETS.TEST = ("cyclone_ds_val", )
predictor = DefaultPredictor(cfg)

# %%
from detectron2.utils.visualizer import ColorMode

for d in random.sample(val_dicts, 15):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    print(outputs)
    # v = Visualizer(im[:, :, ::-1],
    #                metadata=val_metadata, 
    #                scale=0.8, 
    #                instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    # )
    # v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    # cv2_imshow(v.get_image()[:, :, ::-1])
# Out:
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
# {'instances': Instances(num_instances=0, image_height=481, image_width=1440, fields=[pred_boxes: Boxes(tensor([], device='cuda:0', size=(0, 4))), scores: tensor([], device='cuda:0'), pred_classes: tensor([], device='cuda:0', dtype=torch.int64)])}
